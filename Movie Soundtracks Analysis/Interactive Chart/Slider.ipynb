# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
import pandas as pd
import os

# Please run the code in Jupyter (not Spyder) in order for the output to display
# The code below is adapted from the official tutorial of plotly in basic animation
# https://plot.ly/python/animations/

init_notebook_mode(connected=True)


def processData():
    # Change work directory
    # Please change the work directory to where you keep the cleaned_data.csv file
    os.chdir('/Users/ly/Downloads/')

    # Select desired columns
    sel_cols = ['Movie_name','Movie_yr','Movie_genre',
                'Movie_gross','Movie_runtime','Movie_rate']

    # Read data frame and order the column as sel_cols
    dataset = pd.read_csv('cleaned_data.csv', sep=',',encoding='utf-8-sig',
                     usecols =sel_cols)[sel_cols]

    # Drop duplicated movies with the same gross due to our preprocessing of movie titles in Project 1 
    dataset = dataset.drop_duplicates(subset = ['Movie_name','Movie_gross'])

    # Fix movie gross
    # Use log scale of movie gross as the size of the movie node
    # Some movie gross is 0, which actually is less than 0.01 million dollars
    # Fill movie gross = 0 with 0.01
    gross = dataset['Movie_gross']
    gross.replace(to_replace = 0, value = 0.01,inplace = True)
    dataset['Movie_gross'] = gross
    
    return dataset

def slider(dataset):
    # Get unique movie years and genres    
    years = sorted([str(yr) for yr in dataset['Movie_yr'].unique()])
    genres = list(dataset['Movie_genre'])

    # make figure
    figure = {
        'data': [],
        'layout': {},
        'frames': []
    }


    # fill in most of layout
    figure['layout']['xaxis'] = {'range': [7, 10], 'title': 'Rating'}
    figure['layout']['yaxis'] = {'title': 'Run time', 'range':[60,280],'type': 'linear'}
    figure['layout']['hovermode'] = 'closest'
    figure['layout']['sliders'] = {
        'args': [
            'transition', {
                'duration': 400,
                'easing': 'cubic-in-out'
            }
        ],
        'initialValue': years[0],
        'plotlycommand': 'animate',
        'values': years,
        'visible': True
    }
    figure['layout']['updatemenus'] = [
        {
            'buttons': [
                {
                    'args': [None, {'frame': {'duration': 500, 'redraw': False},
                             'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                    'label': 'Play',
                    'method': 'animate'
                },
                {
                    'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                    'transition': {'duration': 0}}],
                    'label': 'Pause',
                    'method': 'animate'
                }
            ],
            'direction': 'left',
            'pad': {'r': 10, 't': 87},
            'showactive': False,
            'type': 'buttons',
            'x': 0.1,
            'xanchor': 'right',
            'y': 0,
            'yanchor': 'top'
        }
    ]

    sliders_dict = {
        'active': 0,
        'yanchor': 'top',
        'xanchor': 'left',
        'currentvalue': {
            'font': {'size': 20},
            'prefix': 'Year:',
            'visible': True,
            'xanchor': 'right'
        },
        'transition': {'duration': 300, 'easing': 'cubic-in-out'},
        'pad': {'b': 10, 't': 50},
        'len': 0.9,
        'x': 0.1,
        'y': 0,
        'steps': []
    }


    # make data
    year = int(years[0])
    for genre in genres:
        dataset_by_year = dataset[dataset['Movie_yr'] == int(year)]
        dataset_by_year_and_movie = dataset_by_year[dataset_by_year['Movie_genre'] == genre]

        data_dict = {
            'x': list(dataset_by_year_and_movie['Movie_rate']),
            'y': list(dataset_by_year_and_movie['Movie_runtime']),
            'mode': 'markers',
            'text': list(dataset_by_year_and_movie['Movie_name']),
            'marker': {
                'sizemode': 'area',
                'sizeref': 3*max(list(dataset['Movie_gross']))/(40**3),
                'size': list(dataset_by_year_and_movie['Movie_gross'])
            },
            'name': genre
        }
        figure['data'].append(data_dict)

    # make frames
    for year in years:
        frame = {'data': [], 'name': year}
        dataset_by_year = dataset[dataset['Movie_yr'] == int(year)]
        genres = dataset_by_year['Movie_genre']
        for genre in genres: 
            dataset_by_year_and_movie= dataset_by_year[dataset_by_year['Movie_genre'] == genre]
            data_dict = {
                'x': list(dataset_by_year_and_movie['Movie_rate']),
                'y': list(dataset_by_year_and_movie['Movie_runtime']),
                'mode': 'markers',
                'text': list(dataset_by_year_and_movie['Movie_name']),
                'marker': {
                    'sizemode': 'area',
                    'sizeref': 3*max(list(dataset['Movie_gross']))/(40**2.7),
                    'size': list(dataset_by_year_and_movie['Movie_gross'])
                },
                'name': genre
            }
            frame['data'].append(data_dict)

        figure['frames'].append(frame)
        slider_step = {'args': [
            [year],
            {'frame': {'duration': 300, 'redraw': False},
             'mode': 'immediate',
           'transition': {'duration': 300}}
         ],
         'label': year,
         'method': 'animate'}
        sliders_dict['steps'].append(slider_step)



    figure['layout']['sliders'] = [sliders_dict]

    iplot(figure, {'config':{'scrollzoom': True}})

def main():
    dataset = processData()
    slider(dataset)
    
if __name__ == "__main__":
    main()
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <div id="0a03881d-e6b4-4ef3-91fe-166c7615596e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '0a03881d-e6b4-4ef3-91fe-166c7615596e',
#             [{"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Adventure, Fantasy", "text": [], "x": [], "y": [], "type": "scatter", "uid": "059cd4f9-2377-4ada-9575-38c361f71586"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Crime, Drama", "text": [], "x": [], "y": [], "type": "scatter", "uid": "85c840b9-a200-4dc8-8053-76c1c998edd8"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Comedy, Romance", "text": [], "x": [], "y": [], "type": "scatter", "uid": "d46c61c9-9b3b-46db-a9db-6060d6c00cc7"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Adventure, Thriller", "text": [], "x": [], "y": [], "type": "scatter", "uid": "968c4e5a-1378-4a51-86a2-ef99cc5a20e7"}, {"marker": {"size": [0.01], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Adventure, Comedy", "text": ["The General"], "x": [8.2], "y": [67], "type": "scatter", "uid": "653d98c7-2b95-4c04-a5b3-e1be88443ddd"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Adventure, Drama, Fantasy", "text": [], "x": [], "y": [], "type": "scatter", "uid": "b2f2d5cd-3d6f-41a4-bc27-f3d8a11cabb3"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Biography, Drama, Musical", "text": [], "x": [], "y": [], "type": "scatter", "uid": "9b1bda0c-342f-4079-b86e-344bd0d336c4"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Drama, Horror, Mystery", "text": [], "x": [], "y": [], "type": "scatter", "uid": "a9ad0db7-2a55-4d34-854b-e7bd406b3338"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Biography, Comedy, Crime", "text": [], "x": [], "y": [], "type": "scatter", "uid": "38cff61b-7d2f-4ee3-b507-00bf6198e797"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Adventure, Sci-Fi", "text": [], "x": [], "y": [], "type": "scatter", "uid": "957e553b-f279-4aae-a7d2-5bd2f9c98392"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Comedy, Fantasy", "text": [], "x": [], "y": [], "type": "scatter", "uid": "a5892100-32ea-4dfe-b627-fbf1d623a1e6"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Comedy, Musical, Romance", "text": [], "x": [], "y": [], "type": "scatter", "uid": "806631d2-4a3b-4261-8b17-ba2fad7991d5"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Crime, Thriller", "text": [], "x": [], "y": [], "type": "scatter", "uid": "d69e6ab1-93ff-41ad-81cc-81cab870c879"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Drama, Romance", "text": [], "x": [], "y": [], "type": "scatter", "uid": "91267da7-3051-4c96-ad63-46f0ddffc3f9"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Adventure, Sci-Fi", "text": [], "x": [], "y": [], "type": "scatter", "uid": "673b1a30-4aa6-4f8c-81d3-a6eaf8f6b4c1"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Horror, Sci-Fi", "text": [], "x": [], "y": [], "type": "scatter", "uid": "22b78014-7970-4a40-90c6-48885625420f"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Action, Adventure, Sci-Fi", "text": [], "x": [], "y": [], "type": "scatter", "uid": "725c1097-9a98-4b18-9cb0-64336b3e467f"}, {"marker": {"size": [], "sizemode": "area", "sizeref": 0.0439059375}, "mode": "markers", "name": "Drama, Horror, Thriller", "text": [], "x": [], "y": [], "type": "scatter", "uid": "3e1082b7-4a45-44f4-a610-fb08 ...
